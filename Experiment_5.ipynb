# %% [markdown]
# <a href="https://colab.research.google.com/github/SivakumarReddy143/Chatbot-Project/blob/main/Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image

# %%
image_path="/landscape.jpg"

# %%
original_image=Image.open(image_path)

# %%
image_array=np.array(original_image)

# %%
cropped_image=image_array[:100,:100,:]

# %%
flipped_image=np.fliplr(cropped_image)

# %%
Image.fromarray(image_array).show()

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=305x204>

# %%
Image.fromarray(cropped_image).show()
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=305x204>

# %%
Image.fromarray(flipped_image).show()
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=305x204>
